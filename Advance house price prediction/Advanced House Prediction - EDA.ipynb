# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.pandas.set_option('display.max_columns',None)

# %% [markdown]
# #### In Data Analysis We will Analyze To Find out the below stuff
# 1. Missing Values
# 2. All The Numerical Variables
# 3. Distribution of the Numerical Variables
# 4. Categorical Variables
# 5. Cardinality of Categorical Variables
# 6. Outliers
# 7. Relationship between independent and dependent feature(SalePrice)

# %%
df=pd.read_csv("train.csv")

df.shape
# Out:
# (1460, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
features_with_NaValues=[feature for feature in df.columns if df[feature].isnull().sum()>1]

for feature in features_with_NaValues:
    print(feature,':',df[feature].isnull().value_counts()[1],'or',np.round(df[feature].isnull().mean()*100,4),'% Missing Values')
    print()
# Out:
# LotFrontage : 259 or 17.7397 % Missing Values
#
# Alley : 1369 or 93.7671 % Missing Values
#
# MasVnrType : 8 or 0.5479 % Missing Values
#
# MasVnrArea : 8 or 0.5479 % Missing Values
#
# BsmtQual : 37 or 2.5342 % Missing Values
#
# BsmtCond : 37 or 2.5342 % Missing Values
#
# BsmtExposure : 38 or 2.6027 % Missing Values
#
# BsmtFinType1 : 37 or 2.5342 % Missing Values
#
# BsmtFinType2 : 38 or 2.6027 % Missing Values
#
# FireplaceQu : 690 or 47.2603 % Missing Values
#
# GarageType : 81 or 5.5479 % Missing Values
#
# GarageYrBlt : 81 or 5.5479 % Missing Values
#
# GarageFinish : 81 or 5.5479 % Missing Values
#
# GarageQual : 81 or 5.5479 % Missing Values
#
# GarageCond : 81 or 5.5479 % Missing Values
#
# PoolQC : 1453 or 99.5205 % Missing Values
#
# Fence : 1179 or 80.7534 % Missing Values
#
# MiscFeature : 1406 or 96.3014 % Missing Values

# %%
#features_with_NaValues
plt.figure(figsize=(20,20))
for i,feature in enumerate(features_with_NaValues,1):
    #print(i,feature)
    data=df.copy()
    data[feature]=np.where(data[feature].isnull(),1,0)
    plt.subplot(5, 4, i)
    data.groupby(feature)['SalePrice'].median().plot(kind='bar',color=['g', 'b']).grid()
    #plt.title(feature)
    #plt.show()

# %% [markdown]
# # Numerical Features

# %%
numerical_features=[feature for feature in df.columns if df[feature].dtypes!='O']


print('Number of numerical variables: ', len(numerical_features))

df[numerical_features].head()
# Out:
# Number of numerical variables:  38
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# #### Temporal Variales(Datetime Variables)

# %%
features_with_year=[feature for feature in df.columns if 'Yr' in feature or 'Year' in feature]
features_with_year
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
# let's explore the content of these year variables
for feature in features_with_year:
    print(feature,':' ,df[feature].nunique(),'Unique Values')
# Out:
# YearBuilt : 112 Unique Values
# YearRemodAdd : 61 Unique Values
# GarageYrBlt : 97 Unique Values
# YrSold : 5 Unique Values

# %%
data["YrSold"] = pd.to_datetime(data["YrSold"].astype(str), format="%Y")
df.groupby('YrSold')['SalePrice'].count().plot()  
plt.title("House Sold VS Year")
# Out:
# Text(0.5, 1.0, 'House Sold VS Year')

# %%
df.groupby('YrSold')['SalePrice'].median().plot()  
plt.xlabel('Year Sold')
plt.ylabel('Median House Price')
plt.title("House Price vs YearSold")
plt.tight_layout()

# %%
features_with_year
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
plt.margins(x=0)
for i in features_with_year:
    data=df.copy()
    if i!='YrSold':
        data[i]=data['YrSold']-data[i]
        ## We will capture the difference between year variable and year the house was sold for
        plt.scatter(data[i],data['SalePrice'])
        plt.xlabel(i)
        plt.ylabel('SalePrice')
        plt.show()

# %%
## Numerical variables are usually of 2 type
## 1. Continous variable and Discrete Variables

discrete_features=[feature for feature in numerical_features 
                if len(df[feature].unique())<25 and feature not in features_with_year+['id']]
print(len(discrete_features))
print((discrete_features))
# Out:
# 17
# ['MSSubClass', 'OverallQual', 'OverallCond', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', '3SsnPorch', 'PoolArea', 'MiscVal', 'MoSold']

# %%
df[discrete_features].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
## Lets Find the realtionship between them and Sale PRice
## Lets Find the realtionship between them and Sale PRice
#plt.figure(figsize=(20,20))
for i,feature in enumerate(discrete_features,1):
    data=df.copy()
    #plt.subplot(7,3,i)
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.tight_layout()
    plt.show()

# %%
continuous_feature=[feature for feature in numerical_features if feature not in discrete_features+features_with_year+['Id']]
print("Continuous feature Count {}".format(len(continuous_feature)))
# Out:
# Continuous feature Count 16

# %%
## Lets analyse the continuous values by creating histograms to understand the distribution

for feature in continuous_feature:
    data=df.copy()
    data[feature].hist(bins=25,ec='black')
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
for feature in continuous_feature:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data['SalePrice']=np.log(data['SalePrice'])
        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalesPrice')
        plt.title(feature)
        plt.show()

# %% [markdown]
# ### Outliers

# %%
for feature in continuous_feature:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# ### Categorical Features

# %%
categorical_features=[feature for feature in df.columns if data[feature].dtypes=='O']
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
df[categorical_features].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
for feature in categorical_features:
    print('The feature is {} and number of categories are {}'.format(feature,(df[feature].nunique())))
# Out:
# The feature is MSZoning and number of categories are 5
# The feature is Street and number of categories are 2
# The feature is Alley and number of categories are 2
# The feature is LotShape and number of categories are 4
# The feature is LandContour and number of categories are 4
# The feature is Utilities and number of categories are 2
# The feature is LotConfig and number of categories are 5
# The feature is LandSlope and number of categories are 3
# The feature is Neighborhood and number of categories are 25
# The feature is Condition1 and number of categories are 9
# The feature is Condition2 and number of categories are 8
# The feature is BldgType and number of categories are 5
# The feature is HouseStyle and number of categories are 8
# The feature is RoofStyle and number of categories are 6
# The feature is RoofMatl and number of categories are 8
# The feature is Exterior1st and number of categories are 15
# The feature is Exterior2nd and number of categories are 16
# ...

# %%
for feature in categorical_features:
    data=df.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %% [raw]
# ### points mentioned below are  reasons for high prices
#
#
# (1)Houses with 2 story 1946  and 1-STORY PUD (Planned Unit Development) sells most
# (2) House with RL and FV MSzone sells most and c lowest
# (3)Pave street,pave alley
# (4)LOTshape-IR2 and IR3 sells most and regular lowest
# (5)Most of the sold houses were having lotFrontage between 4 to 5 mostly 5
# (6)LotArea-9 -10
# (7)LandCantour- HLS Highest,low second highest and bnk lowest
# (8)all utilities
# (9)Lot config- Cul - de sac and fr3
# (10)landslope- moderate and severe
# (11)neighbourhood-Northridge Heights
# (12)condition 1: PosA,poSn,RRNn,RRNe
# (13)condition 2:posa,posn
# (14)bldg type- 1fam,town end unit
# (15)house style2Story,2.5Fin
# (16)overallquality-10,overallcond-5 average
# (17)roofstyle-shed
# (18)Roof material-wood shingles
# (19)Exterior covering on house-stone/cemend board/stucco
# (20)Masonry veneer type-stone
# (21)foundation-pc concrete
# (22)basement height-EX 100+inches
# (23)heating-Gas forced warm air furnace
# (24)central air-yes
# (25)built in garage 3 cars
# (26)pool quality -ex
# (27)fence quality-good
# (28)misc feature -tennis court
# (29)sales cond-partial
# (30)4 bedroom
#
# these points are just overview , will prepare a report separately [More work in progress]

# %%
df.groupby('OverallQual')['SalePrice'].median().plot(kind='bar')
#OverallCond

# %%
df.groupby('OverallCond')['SalePrice'].median().plot(kind='bar')
#OverallCond

# %%
#df.drop_duplicates(['OverallCond','OverallQual','SalePrice'],inplace=True)
pivot = df.pivot_table(index='OverallCond', columns='OverallQual', values='SalePrice',aggfunc='median')
ax = sns.heatmap(pivot,cmap="YlGnBu")
ax.invert_yaxis()
plt.show()

# %%
pivot
# Out:
# OverallQual       1        2         3         4         5         6   \
# OverallCond
# 1            61000.0      NaN       NaN       NaN       NaN       NaN
# 2                NaN      NaN   80750.0   87000.0   67000.0       NaN
# 3            39300.0  47655.5   67000.0  112000.0   85000.0  133250.0
# 4                NaN      NaN   91950.0   98950.0  131500.0  132450.0
# 5                NaN  60000.0  117300.0  111125.0  133350.0  166500.0
# 6                NaN      NaN   72500.0  108504.0  136200.0  155000.0
# 7                NaN      NaN  120000.0  106250.0  132000.0  167000.0
# 8                NaN      NaN  126175.0  105750.0  138000.0  143500.0
# 9                NaN      NaN       NaN  145000.0  124250.0  174000.0
#
# OverallQual        7         8         9         10
# OverallCond
# 1                 NaN       NaN       NaN       NaN
# 2                 NaN       NaN  394432.0       NaN
# 3            197000.0       NaN       NaN       NaN
# ...

# %%
data15=df.copy()
data15['Year-Built']=data15['YrSold']-data15['YearBuilt']
data15['YearRemod-Add']=data15['YearRemodAdd']-data15['YearBuilt']
pivot = data15.pivot_table(index='YearRemod-Add', columns='Year-Built', values='SalePrice',aggfunc='median')
ax = sns.heatmap(pivot,cmap="YlGnBu")
ax.invert_yaxis()
#ax.set(xlim=(0,135),ylim=(0,59))
plt.show()
plt.tight_layout()

# %%
data13['YearRemodAdd']
# Out:
# 0        0
# 1        0
# 2        1
# 3       55
# 4        0
#         ..
# 1455     1
# 1456    10
# 1457    65
# 1458    46
# 1459     0
# Name: YearRemodAdd, Length: 1460, dtype: int64
